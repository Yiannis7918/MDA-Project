# %%
import pandas as pd
import numpy as np
import geopandas as gpd 
import matplotlib as plt
import googlemaps

# %% [markdown]
# # Read the AED file

# %%
aed_coord = pd.read_csv(r"C:\KU Leuven\Modern Data Analytics - MDA\MDA Project\AED_coordinates_NEWEST_2.csv", index_col=False)

# %%
aed_coord.head()
# Out:
#      id              address  number  postal_code municipality province  \
# 0  13.0  blvd. fr. roosevelt      24         7060     soignies  hainaut
# 1  70.0      ch. de wégimont      76         4630      ayeneux    liège
# 2  74.0   rue des prémontrès      12         4020        liège    liège
# 3  75.0    route de bastogne       1         4920        harzé    liège
# 4  76.0          rue du parc       1         4540        jehay    liège
#
#                                  unique_address       points_coordinates  \
# 0  blvd. fr. roosevelt,24,7060,soignies,hainaut  (4.0655019, 50.5767646)
# 1         ch. de wégimont,76,4630,ayeneux,liège  (5.7397828, 50.6105697)
# 2        rue des prémontrès,12,4020,liège,liège  (5.5739754, 50.6380181)
# 3          route de bastogne,1,4920,harzé,liège  (5.6658992, 50.4411102)
# 4                rue du parc,1,4540,jehay,liège  (5.3231573, 50.5772875)
#
#          lat       lng
# 0  50.576765  4.065502
# 1  50.610570  5.739783
# 2  50.638018  5.573975
# 3  50.441110  5.665899
# 4  50.577287  5.323157

# %% [markdown]
# # Create map on the province level - Use Geopandas and Folium

# %%
aed_coord["province"].value_counts()
# Out:
# province
# antwerpen            1558
# hainaut              1287
# liège                1264
# bruxelles-brussel    1192
# oost-vlaanderen      1166
# west-vlaanderen       990
# vlaams-brabant        883
# limburg               757
# namur                 578
# brabant wallon        491
# luxembourg            460
# Name: count, dtype: int64

# %% [markdown]
# ## Read the GeoJSON file of the provinces polygons

# %%
# Read in the neighborhoods geojson file
provinces = gpd.read_file(r"C:\KU Leuven\Modern Data Analytics - MDA\MDA Project\BELGIUM_-_Provinces.geojson")

# Print the first few rows of neighborhoods
print(provinces.head())
# Out:
#    OBJECTID CodeINS           NAME_2  FIRST_NAME  \
# 0         1   10000        Antwerpen  Vlaanderen
# 1         2    4000        Bruxelles   Bruxelles
# 2         3   20001   Vlaams Brabant  Vlaanderen
# 3         4   20002   Brabant Wallon    Wallonie
# 4         5   30000  West-Vlaanderen  Vlaanderen
#
#                                           FIRST_VARN      FIRST_ENGT  \
# 0           Amberes|Antuérpia|Antwerp|Anvers|Anversa        Province
# 1  Brussel Hoofstadt|Brusselse Hoofdstedelijke Ge...  Capital Region
# 2  Brabant Flamand|Brabante Flamenco|Brabante Fla...        Province
# 3       Waals Brabant|Walloon Brabant|Brabante Val?o        Province
# 4  Fiandra Occidentale|Flandes Occidental|Flandre...        Province
#
#                FR_Name          NE_Name  \
# 0               Anvers        Antwerpen
# 1            Bruxelles          Brussel
# 2      Brabant Flamand   Vlaams Brabant
# 3       Brabant Wallon    Waals Brabant
# 4  Flandre Occidentale  West-Vlaanderen
#
#                                             geometry
# 0  MULTIPOLYGON (((4.94209 51.45524, 4.94062 51.4...
# 1  POLYGON ((4.40633 50.91309, 4.40722 50.91295, ...
# 2  POLYGON ((3.98787 50.68749, 3.98772 50.68749, ...
# 3  POLYGON ((4.75386 50.80639, 4.75387 50.80639, ...
# 4  MULTIPOLYGON (((2.65679 51.12932, 2.65663 51.1...

# %%
provinces[["NE_Name","geometry"]]
# Out:
#             NE_Name                                           geometry
# 0         Antwerpen  MULTIPOLYGON (((4.94209 51.45524, 4.94062 51.4...
# 1           Brussel  POLYGON ((4.40633 50.91309, 4.40722 50.91295, ...
# 2    Vlaams Brabant  POLYGON ((3.98787 50.68749, 3.98772 50.68749, ...
# 3     Waals Brabant  POLYGON ((4.75386 50.80639, 4.75387 50.80639, ...
# 4   West-Vlaanderen  MULTIPOLYGON (((2.65679 51.12932, 2.65663 51.1...
# 5   Oost-Vlaanderen  POLYGON ((4.31166 51.29250, 4.31431 51.29112, ...
# 6        Henegouwen  MULTIPOLYGON (((3.71031 50.78190, 3.71065 50.7...
# 7              Luik  POLYGON ((6.13338 50.12956, 6.13309 50.12968, ...
# 8           Limburg  MULTIPOLYGON (((5.77703 50.78285, 5.77662 50.7...
# 9         Luxemburg  POLYGON ((5.43891 50.42170, 5.43908 50.42165, ...
# 10            Namen  POLYGON ((4.97055 50.64532, 4.97142 50.64479, ...

# %% [markdown]
# ## Area of Provinces

# %%
provinces.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
new_provinces = provinces.to_crs(epsg = 3857)

# %%
new_provinces.crs
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# In square meters 
new_provinces.area
# Out:
# 0     7.323998e+09
# 1     4.069907e+08
# 2     5.312589e+09
# 3     2.728216e+09
# 4     7.987316e+09
# 5     7.595941e+09
# 6     9.401428e+09
# 7     9.531529e+09
# 8     6.119002e+09
# 9     1.076397e+10
# 10    8.980230e+09
# dtype: float64

# %%
# Convert to square kilometers 
new_provinces["area_klm2"] = new_provinces.area / 10**6

# %%
new_provinces.to_crs(epsg = 4326, inplace=True)

# %%
area_provinces = new_provinces[["NE_Name","geometry","area_klm2"]]

# %%
area_provinces.plot()
# Out:
# <Axes: >

# %%
area_provinces
# Out:
#             NE_Name                                           geometry  \
# 0         Antwerpen  MULTIPOLYGON (((4.94209 51.45524, 4.94062 51.4...
# 1           Brussel  POLYGON ((4.40633 50.91309, 4.40722 50.91295, ...
# 2    Vlaams Brabant  POLYGON ((3.98787 50.68749, 3.98772 50.68749, ...
# 3     Waals Brabant  POLYGON ((4.75386 50.80639, 4.75387 50.80639, ...
# 4   West-Vlaanderen  MULTIPOLYGON (((2.65679 51.12932, 2.65663 51.1...
# 5   Oost-Vlaanderen  POLYGON ((4.31166 51.29250, 4.31431 51.29112, ...
# 6        Henegouwen  MULTIPOLYGON (((3.71031 50.78190, 3.71065 50.7...
# 7              Luik  POLYGON ((6.13338 50.12956, 6.13309 50.12968, ...
# 8           Limburg  MULTIPOLYGON (((5.77703 50.78285, 5.77662 50.7...
# 9         Luxemburg  POLYGON ((5.43891 50.42170, 5.43908 50.42165, ...
# 10            Namen  POLYGON ((4.97055 50.64532, 4.97142 50.64479, ...
#
#        area_klm2
# 0    7323.997641
# 1     406.990727
# 2    5312.588509
# 3    2728.216099
# 4    7987.315544
# 5    7595.941079
# 6    9401.428447
# 7    9531.529485
# 8    6119.002346
# 9   10763.967091
# 10   8980.230372

# %%
province_name_dict = {"Brussel":"bruxelles-brussel", "Antwerpen":"antwerpen","Vlaams Brabant":"vlaams-brabant", 
"Waals Brabant":"brabant wallon", "West-Vlaanderen":"west-vlaanderen", "Oost-Vlaanderen":"oost-vlaanderen", "Henegouwen":"hainaut",
"Luik":"liège", "Limburg":"limburg", "Luxemburg":"luxembourg", "Namen":"namur"}

# %%
for i in area_provinces.index:
    if area_provinces.loc[i,"NE_Name"] in province_name_dict.keys():
        area_provinces.loc[i,"NE_Name"] = province_name_dict[area_provinces.loc[i,"NE_Name"]]

# %%
area_provinces
# Out:
#               NE_Name                                           geometry  \
# 0           antwerpen  MULTIPOLYGON (((4.94209 51.45524, 4.94062 51.4...
# 1   bruxelles-brussel  POLYGON ((4.40633 50.91309, 4.40722 50.91295, ...
# 2      vlaams-brabant  POLYGON ((3.98787 50.68749, 3.98772 50.68749, ...
# 3      brabant wallon  POLYGON ((4.75386 50.80639, 4.75387 50.80639, ...
# 4     west-vlaanderen  MULTIPOLYGON (((2.65679 51.12932, 2.65663 51.1...
# 5     oost-vlaanderen  POLYGON ((4.31166 51.29250, 4.31431 51.29112, ...
# 6             hainaut  MULTIPOLYGON (((3.71031 50.78190, 3.71065 50.7...
# 7               liège  POLYGON ((6.13338 50.12956, 6.13309 50.12968, ...
# 8             limburg  MULTIPOLYGON (((5.77703 50.78285, 5.77662 50.7...
# 9          luxembourg  POLYGON ((5.43891 50.42170, 5.43908 50.42165, ...
# 10              namur  POLYGON ((4.97055 50.64532, 4.97142 50.64479, ...
#
#        area_klm2
# 0    7323.997641
# 1     406.990727
# 2    5312.588509
# 3    2728.216099
# 4    7987.315544
# 5    7595.941079
# 6    9401.428447
# 7    9531.529485
# 8    6119.002346
# 9   10763.967091
# 10   8980.230372

# %%
area_provinces.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
type(aed_coord)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## GeoDataframe

# %%
# def lat_split(text):
#     lat = float(text.split(',')[0].strip('()'))
#     return lat

# def lng_split(text):
#     lat = float(text.split(',')[1].strip('()'))
#     return lat

# %%
# aed_coord["lat"] = aed_coord["points_coordinates"].apply(lat_split)

# %%
# aed_coord["lng"] = aed_coord["points_coordinates"].apply(lng_split)

# %%
# Create a geometry column 
aed_coord['geometry'] = gpd.points_from_xy(aed_coord["lng"], aed_coord["lat"])

# %%
aed_coord.head()
# Out:
#      id              address  number  postal_code municipality province  \
# 0  13.0  blvd. fr. roosevelt      24         7060     soignies  hainaut
# 1  70.0      ch. de wégimont      76         4630      ayeneux    liège
# 2  74.0   rue des prémontrès      12         4020        liège    liège
# 3  75.0    route de bastogne       1         4920        harzé    liège
# 4  76.0          rue du parc       1         4540        jehay    liège
#
#                                  unique_address       points_coordinates  \
# 0  blvd. fr. roosevelt,24,7060,soignies,hainaut  (4.0655019, 50.5767646)
# 1         ch. de wégimont,76,4630,ayeneux,liège  (5.7397828, 50.6105697)
# 2        rue des prémontrès,12,4020,liège,liège  (5.5739754, 50.6380181)
# 3          route de bastogne,1,4920,harzé,liège  (5.6658992, 50.4411102)
# 4                rue du parc,1,4540,jehay,liège  (5.3231573, 50.5772875)
#
#          lat       lng                  geometry
# 0  50.576765  4.065502  POINT (4.06550 50.57676)
# 1  50.610570  5.739783  POINT (5.73978 50.61057)
# 2  50.638018  5.573975  POINT (5.57398 50.63802)
# 3  50.441110  5.665899  POINT (5.66590 50.44111)
# 4  50.577287  5.323157  POINT (5.32316 50.57729)

# %%
aed_coord.shape
# Out:
# (10626, 11)

# %%
# Create a geodataframe 
aed_geo = gpd.GeoDataFrame(aed_coord, 
                           crs = area_provinces.crs, 
                           geometry = aed_coord["geometry"])
print(type(aed_geo))
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
aed_geo.head()
# Out:
#      id              address  number  postal_code municipality province  \
# 0  13.0  blvd. fr. roosevelt      24         7060     soignies  hainaut
# 1  70.0      ch. de wégimont      76         4630      ayeneux    liège
# 2  74.0   rue des prémontrès      12         4020        liège    liège
# 3  75.0    route de bastogne       1         4920        harzé    liège
# 4  76.0          rue du parc       1         4540        jehay    liège
#
#                                  unique_address       points_coordinates  \
# 0  blvd. fr. roosevelt,24,7060,soignies,hainaut  (4.0655019, 50.5767646)
# 1         ch. de wégimont,76,4630,ayeneux,liège  (5.7397828, 50.6105697)
# 2        rue des prémontrès,12,4020,liège,liège  (5.5739754, 50.6380181)
# 3          route de bastogne,1,4920,harzé,liège  (5.6658992, 50.4411102)
# 4                rue du parc,1,4540,jehay,liège  (5.3231573, 50.5772875)
#
#          lat       lng                  geometry
# 0  50.576765  4.065502  POINT (4.06550 50.57676)
# 1  50.610570  5.739783  POINT (5.73978 50.61057)
# 2  50.638018  5.573975  POINT (5.57398 50.63802)
# 3  50.441110  5.665899  POINT (5.66590 50.44111)
# 4  50.577287  5.323157  POINT (5.32316 50.57729)

# %%
aed_geo.shape
# Out:
# (10626, 11)

# %%
aed_geo.groupby(by="province")["geometry"].count()
# Out:
# province
# antwerpen            1558
# brabant wallon        491
# bruxelles-brussel    1192
# hainaut              1287
# limburg               757
# liège                1264
# luxembourg            460
# namur                 578
# oost-vlaanderen      1166
# vlaams-brabant        883
# west-vlaanderen       990
# Name: geometry, dtype: int64

# %%
aed_geo.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
area_provinces.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
area_provinces.head()
# Out:
#             province                                           geometry  \
# 0          antwerpen  MULTIPOLYGON (((4.94209 51.45524, 4.94062 51.4...
# 1  bruxelles-brussel  POLYGON ((4.40633 50.91309, 4.40722 50.91295, ...
# 2     vlaams-brabant  POLYGON ((3.98787 50.68749, 3.98772 50.68749, ...
# 3     brabant wallon  POLYGON ((4.75386 50.80639, 4.75387 50.80639, ...
# 4    west-vlaanderen  MULTIPOLYGON (((2.65679 51.12932, 2.65663 51.1...
#
#      area_klm2
# 0  7323.997641
# 1   406.990727
# 2  5312.588509
# 3  2728.216099
# 4  7987.315544

# %%
area_provinces.rename(columns={"NE_Name":"province"}, inplace=True)
# Out:
# C:\Users\Johnn\AppData\Local\Temp\ipykernel_33488\2622302863.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   area_provinces.rename(columns={"NE_Name":"province"}, inplace=True)

# %%
area_provinces
# Out:
#              province                                           geometry  \
# 0           antwerpen  MULTIPOLYGON (((4.94209 51.45524, 4.94062 51.4...
# 1   bruxelles-brussel  POLYGON ((4.40633 50.91309, 4.40722 50.91295, ...
# 2      vlaams-brabant  POLYGON ((3.98787 50.68749, 3.98772 50.68749, ...
# 3      brabant wallon  POLYGON ((4.75386 50.80639, 4.75387 50.80639, ...
# 4     west-vlaanderen  MULTIPOLYGON (((2.65679 51.12932, 2.65663 51.1...
# 5     oost-vlaanderen  POLYGON ((4.31166 51.29250, 4.31431 51.29112, ...
# 6             hainaut  MULTIPOLYGON (((3.71031 50.78190, 3.71065 50.7...
# 7               liège  POLYGON ((6.13338 50.12956, 6.13309 50.12968, ...
# 8             limburg  MULTIPOLYGON (((5.77703 50.78285, 5.77662 50.7...
# 9          luxembourg  POLYGON ((5.43891 50.42170, 5.43908 50.42165, ...
# 10              namur  POLYGON ((4.97055 50.64532, 4.97142 50.64479, ...
#
#        area_klm2
# 0    7323.997641
# 1     406.990727
# 2    5312.588509
# 3    2728.216099
# 4    7987.315544
# 5    7595.941079
# 6    9401.428447
# 7    9531.529485
# 8    6119.002346
# 9   10763.967091
# 10   8980.230372

# %%
aed_geo.shape
# Out:
# (10626, 11)

# %%
# Create art_within_neighborhoods by spatially joining art_geo and neighborhoods
aed_within_provinces = gpd.sjoin(aed_geo, area_provinces, predicate = 'within', how="left")

# Print the shape property of art_within_neighborhoods
print(aed_within_provinces.shape)
# Out:
# (10626, 14)

# %%
aed_within_provinces.head()
# Out:
#      id              address  number  postal_code municipality province_left  \
# 0  13.0  blvd. fr. roosevelt      24         7060     soignies       hainaut
# 1  70.0      ch. de wégimont      76         4630      ayeneux         liège
# 2  74.0   rue des prémontrès      12         4020        liège         liège
# 3  75.0    route de bastogne       1         4920        harzé         liège
# 4  76.0          rue du parc       1         4540        jehay         liège
#
#                                  unique_address       points_coordinates  \
# 0  blvd. fr. roosevelt,24,7060,soignies,hainaut  (4.0655019, 50.5767646)
# 1         ch. de wégimont,76,4630,ayeneux,liège  (5.7397828, 50.6105697)
# 2        rue des prémontrès,12,4020,liège,liège  (5.5739754, 50.6380181)
# 3          route de bastogne,1,4920,harzé,liège  (5.6658992, 50.4411102)
# 4                rue du parc,1,4540,jehay,liège  (5.3231573, 50.5772875)
#
#          lat       lng                  geometry  index_right province_right  \
# 0  50.576765  4.065502  POINT (4.06550 50.57676)          6.0        hainaut
# 1  50.610570  5.739783  POINT (5.73978 50.61057)          7.0          liège
# 2  50.638018  5.573975  POINT (5.57398 50.63802)          7.0          liège
# 3  50.441110  5.665899  POINT (5.66590 50.44111)          7.0          liège
# 4  50.577287  5.323157  POINT (5.32316 50.57729)          7.0          liège
#
#      area_klm2
# 0  9401.428447
# 1  9531.529485
# 2  9531.529485
# 3  9531.529485
# 4  9531.529485

# %%
aed_within_provinces.isna().sum()
# Out:
# id                     0
# address                0
# number                 0
# postal_code            0
# municipality           0
# province_left          0
# unique_address         0
# points_coordinates     0
# lat                    0
# lng                    0
# geometry               0
# index_right           18
# province_right        18
# area_klm2             18
# dtype: int64

# %%
aed_within_provinces.groupby("")

# %% [markdown]
# ### Fix problematic coordinates

# %%
problematic_coordinates = aed_within_provinces[aed_within_provinces.isna().any(axis=1)]
# rows_with_na = aed_within_provinces[mask]

# %%
problematic_coordinates
# Out:
#             id                                            address  number  \
# 492     1276.0                                   place de la gare       1
# 604     1466.0                                        rue 2 gares      82
# 1140    2378.0                                   dessous la ville      88
# 1248    2570.0                                     rue des sports      16
# 3475    5870.0                                          grand rue     103
# 5413    8783.0                                     stationsstraat     137
# 5678    9175.0                                  rue du luxembourg      15
# 7208   11484.0                                   alfred devoslaan      50
# 8153   13451.0                    résidence ronnwiss rue ronnwiss       5
# 8154   13452.0  résidence eisknippechen rue des vieilles tanne...      17
# 8199   13545.0                                      halvemaandijk       4
# 9588   15528.0                                            hasselt       1
# 9632   15591.0                             rue christophe plantin       5
# 9699    7724.0                                        gentsevaart      21
# 9777   15712.0                                 rue du 8 septembre      41
# 10388  16278.0                                rue de niederpallen       1
# 10389  16279.0                                         haneboesch       2
# 10408  16307.0                                route de thionville     201
#
#        postal_code             municipality      province_left  \
# 492           6724                houdemont         luxembourg
# 604           1070                bruxelles  bruxelles-brussel
# 1140          6800             saint-pierre         luxembourg
# 1248          6724                houdemont         luxembourg
# 3475          6724                houdemont         luxembourg
# 5413          7327                apeldoorn            hainaut
# 5678          6700                    arlon         luxembourg
# 7208          8670                 koksijde    west-vlaanderen
# 8153          4809                  rodange         luxembourg
# 8154          9572          weidingen-wiltz         luxembourg
# 8199          8400                 oostende    west-vlaanderen
# 9588          9944                   beiler         luxembourg
# 9632          2339  gasperich - luxembourgh         luxembourg
# 9699          4565         kapellebrug (ne)          antwerpen
# 9777          6767               dampicourt         luxembourg
# 10388         8506                  redange         luxembourg
# 10389         4563              differdange         luxembourg
# 10408         5885                luxemburg         luxembourg
#
#                                           unique_address  \
# 492         place de la gare,1,6724,houdemont,luxembourg
# 604      rue 2 gares,82,1070,bruxelles,bruxelles-brussel
# 1140    dessous la ville,88,6800,saint-pierre,luxembourg
# 1248         rue des sports,16,6724,houdemont,luxembourg
# 3475             grand rue,103,6724,houdemont,luxembourg
# 5413           stationsstraat,137,7327,apeldoorn,hainaut
# 5678          rue du luxembourg,15,6700,arlon,luxembourg
# 7208   alfred devoslaan,50,8670,koksijde,west-vlaanderen
# 8153   résidence ronnwiss rue ronnwiss,5,4809,rodange...
# 8154   résidence eisknippechen rue des vieilles tanne...
# 8199       halvemaandijk,4,8400,oostende,west-vlaanderen
# 9588                    hasselt,1,9944,beiler,luxembourg
# 9632   rue christophe plantin,5,2339,gasperich - luxe...
# 9699      gentsevaart,21,4565,kapellebrug (ne),antwerpen
# 9777    rue du 8 septembre,41,6767,dampicourt,luxembourg
# 10388      rue de niederpallen,1,8506,redange,luxembourg
# 10389           haneboesch,2,4563,differdange,luxembourg
# 10408  route de thionville,201,5885,luxemburg,luxembourg
#
#                    points_coordinates        lat        lng  \
# 492           (6.1762513, 48.6445449)  48.644545   6.176251
# 604           (1.2891036, 44.0126679)  44.012668   1.289104
# 1140        (55.4776663, -21.3408775) -21.340878  55.477666
# 1248   (6.129582999999999, 49.815273)  49.815273   6.129583
# 3475          (6.1266275, 49.6120959)  49.612096   6.126627
# 5413     (5.966410499999999, 52.2138)  52.213800   5.966410
# 5678           (5.904159, 49.6587857)  49.658786   5.904159
# 7208          (2.6784715, 51.1355207)  51.135521   2.678472
# 8153   (5.847583999999999, 49.549257)  49.549257   5.847584
# 8154           (5.939982, 49.9709805)  49.970981   5.939982
# 8199          (2.9272377, 51.2382454)  51.238245   2.927238
# 9588           (6.0871872, 50.163953)  50.163953   6.087187
# 9632          (6.1202633, 49.5893732)  49.589373   6.120263
# 9699   (4.0647452, 51.25920559999999)  51.259206   4.064745
# 9777          (1.4159072, 47.6761905)  47.676190   1.415907
# 10388         (5.8901357, 49.7642777)  49.764278   5.890136
# 10389             (5.88896, 49.52273)  49.522730   5.888960
# 10408   (6.143830299999999, 49.58653)  49.586530   6.143830
#
#                          geometry  index_right province_right  area_klm2
# 492      POINT (6.17625 48.64454)          NaN            NaN        NaN
# 604      POINT (1.28910 44.01267)          NaN            NaN        NaN
# 1140   POINT (55.47767 -21.34088)          NaN            NaN        NaN
# 1248     POINT (6.12958 49.81527)          NaN            NaN        NaN
# 3475     POINT (6.12663 49.61210)          NaN            NaN        NaN
# 5413     POINT (5.96641 52.21380)          NaN            NaN        NaN
# 5678     POINT (5.90416 49.65879)          NaN            NaN        NaN
# 7208     POINT (2.67847 51.13552)          NaN            NaN        NaN
# 8153     POINT (5.84758 49.54926)          NaN            NaN        NaN
# 8154     POINT (5.93998 49.97098)          NaN            NaN        NaN
# 8199     POINT (2.92724 51.23825)          NaN            NaN        NaN
# 9588     POINT (6.08719 50.16395)          NaN            NaN        NaN
# 9632     POINT (6.12026 49.58937)          NaN            NaN        NaN
# 9699     POINT (4.06475 51.25921)          NaN            NaN        NaN
# 9777     POINT (1.41591 47.67619)          NaN            NaN        NaN
# 10388    POINT (5.89014 49.76428)          NaN            NaN        NaN
# 10389    POINT (5.88896 49.52273)          NaN            NaN        NaN
# 10408    POINT (6.14383 49.58653)          NaN            NaN        NaN

# %%
gmaps_key = googlemaps.Client(key="AIzaSyCssSY6Q6heYTlvfVRtLmWOpRGGruyEyEQ")

def geocode(add):
    g = gmaps_key.geocode(add)
    if g is not None and isinstance(g, list) and len(g) > 0:
        lat = g[0]["geometry"]["location"]["lat"]
        lng = g[0]["geometry"]["location"]["lng"]
        return (lng, lat)
    else:
        return None

# %%
aed_geo.head()
# Out:
#      id              address  number  postal_code municipality province  \
# 0  13.0  blvd. fr. roosevelt      24         7060     soignies  hainaut
# 1  70.0      ch. de wégimont      76         4630      ayeneux    liège
# 2  74.0   rue des prémontrès      12         4020        liège    liège
# 3  75.0    route de bastogne       1         4920        harzé    liège
# 4  76.0          rue du parc       1         4540        jehay    liège
#
#                                  unique_address       points_coordinates  \
# 0  blvd. fr. roosevelt,24,7060,soignies,hainaut  (4.0655019, 50.5767646)
# 1         ch. de wégimont,76,4630,ayeneux,liège  (5.7397828, 50.6105697)
# 2        rue des prémontrès,12,4020,liège,liège  (5.5739754, 50.6380181)
# 3          route de bastogne,1,4920,harzé,liège  (5.6658992, 50.4411102)
# 4                rue du parc,1,4540,jehay,liège  (5.3231573, 50.5772875)
#
#          lat       lng                  geometry
# 0  50.576765  4.065502  POINT (4.06550 50.57676)
# 1  50.610570  5.739783  POINT (5.73978 50.61057)
# 2  50.638018  5.573975  POINT (5.57398 50.63802)
# 3  50.441110  5.665899  POINT (5.66590 50.44111)
# 4  50.577287  5.323157  POINT (5.32316 50.57729)

# %%
aed_geo.loc[0,"points_coordinates"]
# Out:
# '(4.0655019, 50.5767646)'

# %%
tuple_1 = (5.5840477, 49.7188508)

# %%
str(tuple_1)
# Out:
# '(5.5840477, 49.7188508)'

# %%
index_list = []
row_number = 0
for index, row in aed_geo.iterrows(): 
    for index_2, row_2 in problematic_coordinates.iterrows():
        if row["points_coordinates"] == row_2["points_coordinates"]:
            print(geocode(str(row['postal_code']) + " " + row["municipality"] + " " + row["province"]))
            coordinates = geocode(str(row['postal_code']) + " " + row["municipality"] + " " + row["province"])
            print(type(coordinates))
            index_list.append(index)
            aed_geo.loc[index,"lat"] = coordinates[1]
            aed_geo.loc[index,"lng"] = coordinates[0]
            aed_geo.loc[index,"points_coordinates"] = str(coordinates)
# Out:
# (5.5840477, 49.7188508)
# <class 'tuple'>
# (4.298658400000001, 50.8238652)
# <class 'tuple'>
# (5.3880072, 49.9036915)
# <class 'tuple'>
# (5.5840477, 49.7188508)
# <class 'tuple'>
# (5.5840477, 49.7188508)
# <class 'tuple'>
# (4.062101699999999, 50.5257076)
# <class 'tuple'>
# (5.8166288, 49.68841190000001)
# <class 'tuple'>
# (2.6744402, 51.117577)
# <class 'tuple'>
# (5.8475943, 49.54914420000001)
# <class 'tuple'>
# (5.9396837, 49.9710742)
# <class 'tuple'>
# (2.929598, 51.2161285)
# <class 'tuple'>
# (6.087864799999999, 50.1642676)
# <class 'tuple'>
# (6.120543199999999, 49.5888267)
# <class 'tuple'>
# (4.0650501, 51.2543768)
# <class 'tuple'>
# (5.4759516, 49.5566955)
# <class 'tuple'>
# (5.8941175, 49.7639229)
# <class 'tuple'>
# (5.88896, 49.52273)
# <class 'tuple'>
# (6.1539371, 49.5770811)
# <class 'tuple'>

# %%
len(index_list)
# Out:
# 18

# %%
for i in index_list:
    print(aed_geo.loc[i])
# Out:
# id                                                          1276.0
# address                                           place de la gare
# number                                                           1
# postal_code                                                   6724
# municipality                                             houdemont
# province                                                luxembourg
# unique_address        place de la gare,1,6724,houdemont,luxembourg
# points_coordinates                         (5.5840477, 49.7188508)
# lat                                                      49.718851
# lng                                                       5.584048
# geometry                              POINT (6.1762513 48.6445449)
# Name: 492, dtype: object
# id                                                             1466.0
# address                                                   rue 2 gares
# number                                                             82
# postal_code                                                      1070
# municipality                                                bruxelles
# province                                            bruxelles-brussel
# unique_address        rue 2 gares,82,1070,bruxelles,bruxelles-brussel
# points_coordinates                    (4.298658400000001, 50.8238652)
# lat                                                         50.823865
# lng                                                          4.298658
# geometry                                 POINT (1.2891036 44.0126679)
# Name: 604, dtype: object
# id                                                              2378.0
# address                                               dessous la ville
# number                                                              88
# postal_code                                                       6800
# municipality                                              saint-pierre
# province                                                    luxembourg
# unique_address        dessous la ville,88,6800,saint-pierre,luxembourg
# points_coordinates                             (5.3880072, 49.9036915)
# lat                                                          49.903692
# lng                                                           5.388007
# geometry                                POINT (55.4776663 -21.3408775)
# Name: 1140, dtype: object
# id                                                         2570.0
# address                                            rue des sports
# number                                                         16
# postal_code                                                  6724
# municipality                                            houdemont
# province                                               luxembourg
# unique_address        rue des sports,16,6724,houdemont,luxembourg
# points_coordinates                        (5.5840477, 49.7188508)
# lat                                                     49.718851
# lng                                                      5.584048
# geometry                      POINT (6.129582999999999 49.815273)
# Name: 1248, dtype: object
# id                                                     5870.0
# address                                             grand rue
# number                                                    103
# postal_code                                              6724
# municipality                                        houdemont
# province                                           luxembourg
# unique_address        grand rue,103,6724,houdemont,luxembourg
# points_coordinates                    (5.5840477, 49.7188508)
# lat                                                 49.718851
# lng                                                  5.584048
# geometry                         POINT (6.1266275 49.6120959)
# Name: 3475, dtype: object
# id                                                       8783.0
# address                                          stationsstraat
# number                                                      137
# postal_code                                                7327
# municipality                                          apeldoorn
# province                                                hainaut
# unique_address        stationsstraat,137,7327,apeldoorn,hainaut
# points_coordinates              (4.062101699999999, 50.5257076)
# lat                                                   50.525708
# lng                                                    4.062102
# geometry                      POINT (5.966410499999999 52.2138)
# Name: 5413, dtype: object
# id                                                        9175.0
# address                                        rue du luxembourg
# number                                                        15
# postal_code                                                 6700
# municipality                                               arlon
# province                                              luxembourg
# unique_address        rue du luxembourg,15,6700,arlon,luxembourg
# points_coordinates                (5.8166288, 49.68841190000001)
# lat                                                    49.688412
# lng                                                     5.816629
# geometry                             POINT (5.904159 49.6587857)
# Name: 5678, dtype: object
# id                                                              11484.0
# address                                                alfred devoslaan
# number                                                               50
# postal_code                                                        8670
# municipality                                                   koksijde
# province                                                west-vlaanderen
# unique_address        alfred devoslaan,50,8670,koksijde,west-vlaanderen
# points_coordinates                               (2.6744402, 51.117577)
# lat                                                           51.117577
# lng                                                             2.67444
# geometry                                   POINT (2.6784715 51.1355207)
# Name: 7208, dtype: object
# id                                                              13451.0
# address                                 résidence ronnwiss rue ronnwiss
# number                                                                5
# postal_code                                                        4809
# municipality                                                    rodange
# province                                                     luxembourg
# unique_address        résidence ronnwiss rue ronnwiss,5,4809,rodange...
# points_coordinates                       (5.8475943, 49.54914420000001)
# lat                                                           49.549144
# lng                                                            5.847594
# geometry                            POINT (5.847583999999999 49.549257)
# Name: 8153, dtype: object
# id                                                              13452.0
# address               résidence eisknippechen rue des vieilles tanne...
# number                                                               17
# postal_code                                                        9572
# municipality                                            weidingen-wiltz
# province                                                     luxembourg
# unique_address        résidence eisknippechen rue des vieilles tanne...
# points_coordinates                              (5.9396837, 49.9710742)
# lat                                                           49.971074
# lng                                                            5.939684
# geometry                                    POINT (5.939982 49.9709805)
# Name: 8154, dtype: object
# id                                                          13545.0
# address                                               halvemaandijk
# number                                                            4
# postal_code                                                    8400
# municipality                                               oostende
# province                                            west-vlaanderen
# unique_address        halvemaandijk,4,8400,oostende,west-vlaanderen
# points_coordinates                           (2.929598, 51.2161285)
# lat                                                       51.216129
# lng                                                        2.929598
# geometry                               POINT (2.9272377 51.2382454)
# Name: 8199, dtype: object
# id                                             15528.0
# address                                        hasselt
# number                                               1
# postal_code                                       9944
# municipality                                    beiler
# province                                    luxembourg
# unique_address        hasselt,1,9944,beiler,luxembourg
# points_coordinates     (6.087864799999999, 50.1642676)
# lat                                          50.164268
# lng                                           6.087865
# geometry                   POINT (6.0871872 50.163953)
# Name: 9588, dtype: object
# id                                                              15591.0
# address                                          rue christophe plantin
# number                                                                5
# postal_code                                                        2339
# municipality                                    gasperich - luxembourgh
# province                                                     luxembourg
# unique_address        rue christophe plantin,5,2339,gasperich - luxe...
# points_coordinates                      (6.120543199999999, 49.5888267)
# lat                                                           49.588827
# lng                                                            6.120543
# geometry                                   POINT (6.1202633 49.5893732)
# Name: 9632, dtype: object
# id                                                            7724.0
# address                                                  gentsevaart
# number                                                            21
# postal_code                                                     4565
# municipality                                        kapellebrug (ne)
# province                                                   antwerpen
# unique_address        gentsevaart,21,4565,kapellebrug (ne),antwerpen
# points_coordinates                           (4.0650501, 51.2543768)
# lat                                                        51.254377
# lng                                                          4.06505
# geometry                         POINT (4.0647452 51.25920559999999)
# Name: 9699, dtype: object
# id                                                             15712.0
# address                                             rue du 8 septembre
# number                                                              41
# postal_code                                                       6767
# municipality                                                dampicourt
# province                                                    luxembourg
# unique_address        rue du 8 septembre,41,6767,dampicourt,luxembourg
# points_coordinates                             (5.4759516, 49.5566955)
# lat                                                          49.556695
# lng                                                           5.475952
# geometry                                  POINT (1.4159072 47.6761905)
# Name: 9777, dtype: object
# id                                                          16278.0
# address                                         rue de niederpallen
# number                                                            1
# postal_code                                                    8506
# municipality                                                redange
# province                                                 luxembourg
# unique_address        rue de niederpallen,1,8506,redange,luxembourg
# points_coordinates                          (5.8941175, 49.7639229)
# lat                                                       49.763923
# lng                                                        5.894118
# geometry                               POINT (5.8901357 49.7642777)
# Name: 10388, dtype: object
# id                                                     16279.0
# address                                             haneboesch
# number                                                       2
# postal_code                                               4563
# municipality                                       differdange
# province                                            luxembourg
# unique_address        haneboesch,2,4563,differdange,luxembourg
# points_coordinates                         (5.88896, 49.52273)
# lat                                                   49.52273
# lng                                                    5.88896
# geometry                              POINT (5.88896 49.52273)
# Name: 10389, dtype: object
# id                                                              16307.0
# address                                             route de thionville
# number                                                              201
# postal_code                                                        5885
# municipality                                                  luxemburg
# province                                                     luxembourg
# unique_address        route de thionville,201,5885,luxemburg,luxembourg
# points_coordinates                              (6.1539371, 49.5770811)
# lat                                                           49.577081
# lng                                                            6.153937
# geometry                             POINT (6.143830299999999 49.58653)
# Name: 10408, dtype: object

# %%
aed_geo.head()
# Out:
#      id              address  number  postal_code municipality province  \
# 0  13.0  blvd. fr. roosevelt      24         7060     soignies  hainaut
# 1  70.0      ch. de wégimont      76         4630      ayeneux    liège
# 2  74.0   rue des prémontrès      12         4020        liège    liège
# 3  75.0    route de bastogne       1         4920        harzé    liège
# 4  76.0          rue du parc       1         4540        jehay    liège
#
#                                  unique_address       points_coordinates  \
# 0  blvd. fr. roosevelt,24,7060,soignies,hainaut  (4.0655019, 50.5767646)
# 1         ch. de wégimont,76,4630,ayeneux,liège  (5.7397828, 50.6105697)
# 2        rue des prémontrès,12,4020,liège,liège  (5.5739754, 50.6380181)
# 3          route de bastogne,1,4920,harzé,liège  (5.6658992, 50.4411102)
# 4                rue du parc,1,4540,jehay,liège  (5.3231573, 50.5772875)
#
#          lat       lng                  geometry
# 0  50.576765  4.065502  POINT (4.06550 50.57676)
# 1  50.610570  5.739783  POINT (5.73978 50.61057)
# 2  50.638018  5.573975  POINT (5.57398 50.63802)
# 3  50.441110  5.665899  POINT (5.66590 50.44111)
# 4  50.577287  5.323157  POINT (5.32316 50.57729)

# %%
# Create a geometry column 
aed_geo['geometry'] = gpd.points_from_xy(aed_geo["lng"], aed_geo["lat"])

# %%
# Create a geodataframe 
aed_geo = gpd.GeoDataFrame(aed_geo, 
                           crs = area_provinces.crs, 
                           geometry = aed_geo["geometry"])
print(type(aed_geo))
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
aed_geo.loc[492]
# Out:
# id                                                          1276.0
# address                                           place de la gare
# number                                                           1
# postal_code                                                   6724
# municipality                                             houdemont
# province                                                luxembourg
# unique_address        place de la gare,1,6724,houdemont,luxembourg
# points_coordinates                         (5.5840477, 49.7188508)
# lat                                                      49.718851
# lng                                                       5.584048
# geometry                              POINT (5.5840477 49.7188508)
# Name: 492, dtype: object

# %%
type(area_provinces)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
aed_geo.head()
# Out:
#      id              address  number  postal_code municipality province  \
# 0  13.0  blvd. fr. roosevelt      24         7060     soignies  hainaut
# 1  70.0      ch. de wégimont      76         4630      ayeneux    liège
# 2  74.0   rue des prémontrès      12         4020        liège    liège
# 3  75.0    route de bastogne       1         4920        harzé    liège
# 4  76.0          rue du parc       1         4540        jehay    liège
#
#                                  unique_address       points_coordinates  \
# 0  blvd. fr. roosevelt,24,7060,soignies,hainaut  (4.0655019, 50.5767646)
# 1         ch. de wégimont,76,4630,ayeneux,liège  (5.7397828, 50.6105697)
# 2        rue des prémontrès,12,4020,liège,liège  (5.5739754, 50.6380181)
# 3          route de bastogne,1,4920,harzé,liège  (5.6658992, 50.4411102)
# 4                rue du parc,1,4540,jehay,liège  (5.3231573, 50.5772875)
#
#          lat       lng                  geometry
# 0  50.576765  4.065502  POINT (4.06550 50.57676)
# 1  50.610570  5.739783  POINT (5.73978 50.61057)
# 2  50.638018  5.573975  POINT (5.57398 50.63802)
# 3  50.441110  5.665899  POINT (5.66590 50.44111)
# 4  50.577287  5.323157  POINT (5.32316 50.57729)

# %%
aed_geo.to_csv('C:\KU Leuven\Modern Data Analytics - MDA\MDA Project\AED_geo_new.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 aed_geo.to_csv('C:\KU Leuven\Modern Data Analytics - MDA\MDA Project\AED_geo_new.csv', index=False)
#
# NameError: name 'aed_geo' is not defined

# %%
# Create art_within_neighborhoods by spatially joining art_geo and neighborhoods
aed_within_provinces = gpd.sjoin(aed_geo, area_provinces, predicate = 'within', how="left")

# Print the shape property of art_within_neighborhoods
print(aed_within_provinces.shape)
# Out:
# (10626, 14)

# %%
aed_within_provinces.to_csv('C:\KU Leuven\Modern Data Analytics - MDA\MDA Project\AED_within_provinces.csv', index=False)

# %%
aed_within_provinces = pd.read_csv(r'C:\KU Leuven\Modern Data Analytics - MDA\MDA Project\AED_within_provinces.csv')
aed_geo = pd.read_csv(r"C:\KU Leuven\Modern Data Analytics - MDA\MDA Project\AED_geo_new.csv")

# %%
# Create a geodataframe 
# Create a geometry column 
aed_geo['geometry'] = gpd.points_from_xy(aed_geo["lng"], aed_geo["lat"])

aed_geo = gpd.GeoDataFrame(aed_geo, 
                           crs = area_provinces.crs, 
                           geometry = aed_geo["geometry"])
print(type(aed_geo))
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
type(area_provinces)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
type(aed_geo)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
aed_within_provinces.isna().sum()
# Out:
# id                    0
# address               0
# number                0
# postal_code           0
# municipality          0
# province_left         0
# unique_address        0
# points_coordinates    0
# lat                   0
# lng                   0
# geometry              0
# index_right           8
# province_right        8
# area_klm2             8
# dtype: int64

# %%
type(aed_within_provinces)
# Out:
# pandas.core.frame.DataFrame

# %%
# Create art_within_neighborhoods by spatially joining art_geo and neighborhoods
aed_within_provinces = gpd.sjoin(aed_geo, area_provinces, predicate = 'within', how="left")

# Print the shape property of art_within_neighborhoods
print(aed_within_provinces.shape)
# Out:
# (10626, 14)

# %%
aed_within_provinces.isna().sum()
# Out:
# id                    0
# address               0
# number                0
# postal_code           0
# municipality          0
# province_left         0
# unique_address        0
# points_coordinates    0
# lat                   0
# lng                   0
# geometry              0
# index_right           8
# province_right        8
# area_klm2             8
# dtype: int64

# %%
aed_within_provinces.head()
# Out:
#      id              address  number  postal_code municipality province_left  \
# 0  13.0  blvd. fr. roosevelt      24         7060     soignies       hainaut
# 1  70.0      ch. de wégimont      76         4630      ayeneux         liège
# 2  74.0   rue des prémontrès      12         4020        liège         liège
# 3  75.0    route de bastogne       1         4920        harzé         liège
# 4  76.0          rue du parc       1         4540        jehay         liège
#
#                                  unique_address       points_coordinates  \
# 0  blvd. fr. roosevelt,24,7060,soignies,hainaut  (4.0655019, 50.5767646)
# 1         ch. de wégimont,76,4630,ayeneux,liège  (5.7397828, 50.6105697)
# 2        rue des prémontrès,12,4020,liège,liège  (5.5739754, 50.6380181)
# 3          route de bastogne,1,4920,harzé,liège  (5.6658992, 50.4411102)
# 4                rue du parc,1,4540,jehay,liège  (5.3231573, 50.5772875)
#
#          lat       lng                  geometry  index_right province_right  \
# 0  50.576765  4.065502  POINT (4.06550 50.57676)          6.0        hainaut
# 1  50.610570  5.739783  POINT (5.73978 50.61057)          7.0          liège
# 2  50.638018  5.573975  POINT (5.57398 50.63802)          7.0          liège
# 3  50.441110  5.665899  POINT (5.66590 50.44111)          7.0          liège
# 4  50.577287  5.323157  POINT (5.32316 50.57729)          7.0          liège
#
#      area_klm2
# 0  9401.428447
# 1  9531.529485
# 2  9531.529485
# 3  9531.529485
# 4  9531.529485

# %%
aed_geo.head()
# Out:
#      id              address  number  postal_code municipality province  \
# 0  13.0  blvd. fr. roosevelt      24         7060     soignies  hainaut
# 1  70.0      ch. de wégimont      76         4630      ayeneux    liège
# 2  74.0   rue des prémontrès      12         4020        liège    liège
# 3  75.0    route de bastogne       1         4920        harzé    liège
# 4  76.0          rue du parc       1         4540        jehay    liège
#
#                                  unique_address       points_coordinates  \
# 0  blvd. fr. roosevelt,24,7060,soignies,hainaut  (4.0655019, 50.5767646)
# 1         ch. de wégimont,76,4630,ayeneux,liège  (5.7397828, 50.6105697)
# 2        rue des prémontrès,12,4020,liège,liège  (5.5739754, 50.6380181)
# 3          route de bastogne,1,4920,harzé,liège  (5.6658992, 50.4411102)
# 4                rue du parc,1,4540,jehay,liège  (5.3231573, 50.5772875)
#
#          lat       lng                  geometry
# 0  50.576765  4.065502  POINT (4.06550 50.57676)
# 1  50.610570  5.739783  POINT (5.73978 50.61057)
# 2  50.638018  5.573975  POINT (5.57398 50.63802)
# 3  50.441110  5.665899  POINT (5.66590 50.44111)
# 4  50.577287  5.323157  POINT (5.32316 50.57729)

# %%
area_provinces
# Out:
#              province                                           geometry  \
# 0           antwerpen  MULTIPOLYGON (((4.94209 51.45524, 4.94062 51.4...
# 1   bruxelles-brussel  POLYGON ((4.40633 50.91309, 4.40722 50.91295, ...
# 2      vlaams-brabant  POLYGON ((3.98787 50.68749, 3.98772 50.68749, ...
# 3      brabant wallon  POLYGON ((4.75386 50.80639, 4.75387 50.80639, ...
# 4     west-vlaanderen  MULTIPOLYGON (((2.65679 51.12932, 2.65663 51.1...
# 5     oost-vlaanderen  POLYGON ((4.31166 51.29250, 4.31431 51.29112, ...
# 6             hainaut  MULTIPOLYGON (((3.71031 50.78190, 3.71065 50.7...
# 7               liège  POLYGON ((6.13338 50.12956, 6.13309 50.12968, ...
# 8             limburg  MULTIPOLYGON (((5.77703 50.78285, 5.77662 50.7...
# 9          luxembourg  POLYGON ((5.43891 50.42170, 5.43908 50.42165, ...
# 10              namur  POLYGON ((4.97055 50.64532, 4.97142 50.64479, ...
#
#        area_klm2
# 0    7323.997641
# 1     406.990727
# 2    5312.588509
# 3    2728.216099
# 4    7987.315544
# 5    7595.941079
# 6    9401.428447
# 7    9531.529485
# 8    6119.002346
# 9   10763.967091
# 10   8980.230372

# %%
aed_within_provinces[aed_within_provinces.isna().any(axis=1)]
# Out:
#             id                                            address  number  \
# 8153   13451.0                    résidence ronnwiss rue ronnwiss       5
# 8154   13452.0  résidence eisknippechen rue des vieilles tanne...      17
# 9588   15528.0                                            hasselt       1
# 9632   15591.0                             rue christophe plantin       5
# 9699    7724.0                                        gentsevaart      21
# 10388  16278.0                                rue de niederpallen       1
# 10389  16279.0                                         haneboesch       2
# 10408  16307.0                                route de thionville     201
#
#        postal_code             municipality province_left  \
# 8153          4809                  rodange    luxembourg
# 8154          9572          weidingen-wiltz    luxembourg
# 9588          9944                   beiler    luxembourg
# 9632          2339  gasperich - luxembourgh    luxembourg
# 9699          4565         kapellebrug (ne)     antwerpen
# 10388         8506                  redange    luxembourg
# 10389         4563              differdange    luxembourg
# 10408         5885                luxemburg    luxembourg
#
#                                           unique_address  \
# 8153   résidence ronnwiss rue ronnwiss,5,4809,rodange...
# 8154   résidence eisknippechen rue des vieilles tanne...
# 9588                    hasselt,1,9944,beiler,luxembourg
# 9632   rue christophe plantin,5,2339,gasperich - luxe...
# 9699      gentsevaart,21,4565,kapellebrug (ne),antwerpen
# 10388      rue de niederpallen,1,8506,redange,luxembourg
# 10389           haneboesch,2,4563,differdange,luxembourg
# 10408  route de thionville,201,5885,luxemburg,luxembourg
#
#                     points_coordinates        lat       lng  \
# 8153    (5.8475943, 49.54914420000001)  49.549144  5.847594
# 8154           (5.9396837, 49.9710742)  49.971074  5.939684
# 9588   (6.087864799999999, 50.1642676)  50.164268  6.087865
# 9632   (6.120543199999999, 49.5888267)  49.588827  6.120543
# 9699           (4.0650501, 51.2543768)  51.254377  4.065050
# 10388          (5.8941175, 49.7639229)  49.763923  5.894118
# 10389              (5.88896, 49.52273)  49.522730  5.888960
# 10408          (6.1539371, 49.5770811)  49.577081  6.153937
#
#                        geometry  index_right province_right  area_klm2
# 8153   POINT (5.84759 49.54914)          NaN            NaN        NaN
# 8154   POINT (5.93968 49.97107)          NaN            NaN        NaN
# 9588   POINT (6.08786 50.16427)          NaN            NaN        NaN
# 9632   POINT (6.12054 49.58883)          NaN            NaN        NaN
# 9699   POINT (4.06505 51.25438)          NaN            NaN        NaN
# 10388  POINT (5.89412 49.76392)          NaN            NaN        NaN
# 10389  POINT (5.88896 49.52273)          NaN            NaN        NaN
# 10408  POINT (6.15394 49.57708)          NaN            NaN        NaN

# %%
aed_within_provinces.shape
# Out:
# (10626, 14)

# %%
# Remove these 8 NAs since they are not located in Belgium 
aed_within_provinces.dropna(inplace=True)

# %%
aed_within_provinces.shape
# Out:
# (10618, 14)

# %%
type(aed_within_provinces)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
aed_within_provinces.to_csv('C:\KU Leuven\Modern Data Analytics - MDA\MDA Project\AED_within_provinces_2.csv', index=False)

# %% [markdown]
# ### Save area_provinces, aed_geo, aed_within_provinces as geojson

# %%
# area provinces
area_provinces.to_file("C:\KU Leuven\Modern Data Analytics - MDA\MDA Project\AREA_PROVINCES.geojson", driver='GeoJSON') 
# aed_within_provinces 
aed_within_provinces.to_file("C:\KU Leuven\Modern Data Analytics - MDA\MDA Project\AED_WITHIN_PROVINCES.geojson", driver='GeoJSON') 
# aed_geo 
aed_geo.to_file("C:\KU Leuven\Modern Data Analytics - MDA\MDA Project\AED_GEO.geojson", driver='GeoJSON')

# %% [markdown]
# ### Save area_provinces, aed_geo, aed_within_provinces as geojson

# %%
# area provinces
area_provinces.to_csv('C:\KU Leuven\Modern Data Analytics - MDA\MDA Project\AREA_PROVINCES.csv', index=False)
# aed_within_provinces 
aed_within_provinces.to_csv('C:\KU Leuven\Modern Data Analytics - MDA\MDA Project\AED_WITHIN_PROVINCES.csv', index=False)
# aed_geo
aed_geo.to_csv('C:\KU Leuven\Modern Data Analytics - MDA\MDA Project\AED_GEO.csv', index=False)

# %% [markdown]
# # Plot the AED on top of the provinces in the map of Belgium

# %%
area_provinces = gpd.read_file("C:\KU Leuven\Modern Data Analytics - MDA\MDA Project\AREA_PROVINCES.geojson")

# %%
area_provinces
# Out:
#              province     area_klm2  \
# 0           antwerpen   7323.997641
# 1   bruxelles-brussel    406.990727
# 2      vlaams-brabant   5312.588509
# 3      brabant wallon   2728.216099
# 4     west-vlaanderen   7987.315544
# 5     oost-vlaanderen   7595.941079
# 6             hainaut   9401.428447
# 7               liège   9531.529485
# 8             limburg   6119.002346
# 9          luxembourg  10763.967091
# 10              namur   8980.230372
#
#                                              geometry
# 0   MULTIPOLYGON (((4.94209 51.45524, 4.94062 51.4...
# 1   POLYGON ((4.40633 50.91309, 4.40722 50.91295, ...
# 2   POLYGON ((3.98787 50.68749, 3.98772 50.68749, ...
# 3   POLYGON ((4.75386 50.80639, 4.75387 50.80639, ...
# 4   MULTIPOLYGON (((2.65679 51.12932, 2.65663 51.1...
# 5   POLYGON ((4.31166 51.29250, 4.31431 51.29112, ...
# 6   MULTIPOLYGON (((3.71031 50.78190, 3.71065 50.7...
# 7   POLYGON ((6.13338 50.12956, 6.13309 50.12968, ...
# 8   MULTIPOLYGON (((5.77703 50.78285, 5.77662 50.7...
# 9   POLYGON ((5.43891 50.42170, 5.43908 50.42165, ...
# 10  POLYGON ((4.97055 50.64532, 4.97142 50.64479, ...

# %%
type(area_provinces)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
aed_within_provinces = gpd.read_file("C:\KU Leuven\Modern Data Analytics - MDA\MDA Project\AED_WITHIN_PROVINCES.geojson")

# %%
aed_within_provinces.head()
# Out:
#      id              address  number  postal_code municipality province_left  \
# 0  13.0  blvd. fr. roosevelt      24         7060     soignies       hainaut
# 1  70.0      ch. de wégimont      76         4630      ayeneux         liège
# 2  74.0   rue des prémontrès      12         4020        liège         liège
# 3  75.0    route de bastogne       1         4920        harzé         liège
# 4  76.0          rue du parc       1         4540        jehay         liège
#
#                                  unique_address       points_coordinates  \
# 0  blvd. fr. roosevelt,24,7060,soignies,hainaut  (4.0655019, 50.5767646)
# 1         ch. de wégimont,76,4630,ayeneux,liège  (5.7397828, 50.6105697)
# 2        rue des prémontrès,12,4020,liège,liège  (5.5739754, 50.6380181)
# 3          route de bastogne,1,4920,harzé,liège  (5.6658992, 50.4411102)
# 4                rue du parc,1,4540,jehay,liège  (5.3231573, 50.5772875)
#
#          lat       lng  index_right province_right    area_klm2  \
# 0  50.576765  4.065502          6.0        hainaut  9401.428447
# 1  50.610570  5.739783          7.0          liège  9531.529485
# 2  50.638018  5.573975          7.0          liège  9531.529485
# 3  50.441110  5.665899          7.0          liège  9531.529485
# 4  50.577287  5.323157          7.0          liège  9531.529485
#
#                    geometry
# 0  POINT (4.06550 50.57676)
# 1  POINT (5.73978 50.61057)
# 2  POINT (5.57398 50.63802)
# 3  POINT (5.66590 50.44111)
# 4  POINT (5.32316 50.57729)
